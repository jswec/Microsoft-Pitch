# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Russell Blanchard
# * Student pace: full time
# * Scheduled project review date/time: 1/27/23
# * Instructor name: Angelica Spratley
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib.pyplot import figure
import warnings
import glob
import zipfile
warnings.filterwarnings('ignore')

# %%
collaborators_df = pd.read_csv('collaborators 2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-466554fa2bc0> in <module>
# ----> 1 collaborators_df = pd.read_csv('collaborators 2.csv')
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
all_genres_and_budgets_df = pd.read_csv('all_genres_vs_budgets 2.csv')

# %%
master_joined_df = collaborators_df.join(all_genres_and_budgets_df, how ='outer')

# %%
master_joined_df
# Out:
#          movie_id                    primary_title  start_year  \
# 0       tt0066787  One Day Before the Rainy Season        2019
# 1       tt0066787  One Day Before the Rainy Season        2019
# 2       tt0066787  One Day Before the Rainy Season        2019
# 3       tt0066787  One Day Before the Rainy Season        2019
# 4       tt0066787  One Day Before the Rainy Season        2019
# ...           ...                              ...         ...
# 298485  tt9916428              The Secret of China        2019
# 298486  tt9916538              Kuambil Lagi Hatiku        2019
# 298487  tt9916538              Kuambil Lagi Hatiku        2019
# 298488  tt9916538              Kuambil Lagi Hatiku        2019
# 298489  tt9916538              Kuambil Lagi Hatiku        2019
#
#                        genres   person_id  category            job  \
# 0             Biography,Drama   nm0045119   actress            NaN
# 1             Biography,Drama   nm0451809     actor            NaN
# ...

# %%
master_joined_df.to_csv('master.csv', index=False)

# %%
# !ls
# Out:
# Beyza-Genre&Rating.ipynb Leo Notebook 2.ipynb     final.ipynb
# Horror.csv               Leo.ipynb                russmasterdata.ipynb
# Jake.ipynb               Russell.ipynb
# Leo 3.ipynb              exploratory.ipynb
