# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
table_data=[
    ["Action" ,28],
    ["Adventure" ,12],
    ["Animation", 16],
    ["Comedy" ,35],
    ["Crime" ,80],
    ["Documentary" ,99],
    ["Drama", 18],
    ["Family", 10751],
    ["Fantasy", 14],
    ["History", 36],
    ["Horror" ,27],
    ["Music",10402],
    ["Mystery" ,9648],
    ["Romance" ,10749],
    ["Science Fiction", 878],
    ["TV Movie",10770],
    ["Thriller",53],
    ["War",10752],
    ["Western", 37]
]
table = ax.table(cellText=table_data, loc='center')
table.set_fontsize(15)
table.scale(1,3)
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
tmdb=pd.read_csv('C:/Users/Beyza/documents/flatiron/phase 1/DS-NATL-010923/p1_project/Microsoft-Pitch/zippedData/tmdb.movies.csv.gz')

# %%
tmdb.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tmdb['release_date'] = pd.to_datetime(tmdb['release_date'])

print(type(tmdb.release_date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
tmdb.sort_values(by='release_date',ascending=False)
tmdb.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tmdb.sort_values(by='release_date', inplace=True)
tmdb.tail(100)
# Out:
#        Unnamed: 0                     genre_ids      id original_language  \
# 25438       25438                   [35, 10749]  551701                en
# 25469       25469                          [27]  517939                en
# 25293       25293                [10751, 10770]  555281                en
# 26080       26080                      [27, 18]  578680                en
# 25042       25042                [10770, 10749]  550035                en
# ...           ...                           ...     ...               ...
# 24819       24819                          [18]  481880                en
# 24003       24003                [18, 9648, 53]  411144                en
# 24892       24892                          [99]  541577                en
# 24265       24265                   [10749, 18]  428836                en
# 26057       26057  [27, 80, 80, 80, 80, 80, 80]  570704                en
#
#                            original_title  popularity release_date  \
# ...

# %%
filtered_tmdb = tmdb.loc[(tmdb['release_date'] >= '2018-12-22')
                     & (tmdb['release_date'] < '2020-12-25')]
filtered_tmdb.head()
# Out:
#        Unnamed: 0           genre_ids      id original_language  \
# 25123       25123  [18, 10749, 10770]  555277                en
# 24870       24870      [10749, 10770]  550024                en
# 25438       25438         [35, 10749]  551701                en
# 25469       25469                [27]  517939                en
# 25293       25293      [10751, 10770]  555281                en
#
#                     original_title  popularity release_date  \
# 25123         Small Town Christmas       2.788   2018-12-22
# 24870    Christmas at Grand Valley       4.101   2018-12-22
# 25438      Jingle Around the Clock       1.997   2018-12-22
# 25469            Paranormal Demons       1.940   2018-12-23
# 25293  Christmas Bells Are Ringing       2.308   2018-12-23
#
#                              title  vote_average  vote_count
# 25123         Small Town Christmas           5.9           8
# 24870    Christmas at Grand Valley           7.3           3
# ...

# %%
filtered_tmdb.drop(columns=['id','original_language','original_title','vote_average','vote_count','Unnamed: 0'])
# Out:
#                 genre_ids  popularity release_date  \
# 25123  [18, 10749, 10770]       2.788   2018-12-22
# 24870      [10749, 10770]       4.101   2018-12-22
# 25438         [35, 10749]       1.997   2018-12-22
# 25469                [27]       1.940   2018-12-23
# 25293      [10751, 10770]       2.308   2018-12-23
# ...                   ...         ...          ...
# 24297                [18]       8.316   2019-05-17
# 24819                [18]       4.480   2019-05-17
# 24003      [18, 9648, 53]      14.028   2019-05-17
# 24892                [99]       3.955   2019-06-28
# 24265         [10749, 18]       8.715   2019-06-28
#
#                                     title
# 25123                Small Town Christmas
# 24870           Christmas at Grand Valley
# 25438             Jingle Around the Clock
# 25469                   Paranormal Demons
# 25293         Christmas Bells Are Ringing
# ...                                   ...
# 24297            All Creatures Here Below
# ...

# %%
tmdb['popularity'].max()
# Out:
# 80.773
